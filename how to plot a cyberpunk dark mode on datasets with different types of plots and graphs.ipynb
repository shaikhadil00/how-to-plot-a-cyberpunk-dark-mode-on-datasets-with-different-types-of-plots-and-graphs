# %%
import matplotlib.pyplot as plt
import mplcyberpunk
from sklearn import datasets

# %%
# Load the dataset
data = datasets.load_iris()

# %% [markdown]
# # Scatter plot

# %%
# Scatter plot
plt.scatter(data.data[:, 0], data.data[:, 1], c=data.target)
mplcyberpunk.add_glow_effects()
mplcyberpunk.make_lines_glow()
mplcyberpunk.add_underglow()
plt.show()

# %% [markdown]
# # line plot

# %%
# Line plot
plt.plot(data.data[:, 0], data.data[:, 1])
mplcyberpunk.add_glow_effects()
mplcyberpunk.make_lines_glow()
mplcyberpunk.add_underglow()
plt.show()

# %% [markdown]
# # Histogram

# %%
# Histogram
plt.hist(data.data[:, 0], bins=10)
mplcyberpunk.add_glow_effects()
mplcyberpunk.make_lines_glow()
mplcyberpunk.add_underglow()
plt.show()

# %% [markdown]
# # Barplot

# %%
import seaborn as sns
import pandas as pd
# Out:
# C:\Users\ADIL SHAIKH\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\ADIL SHAIKH\Anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
iris = sns.load_dataset('iris')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='species', y='sepal_length', data=iris, ci=None)

# Add the Cyberpunk theme to the plot
mplcyberpunk.add_glow_effects()

# Set the title and labels with a Cyberpunk 'Dark Mode' theme
plt.title('Cyberpunk "Dark Mode" Bar Plot of Iris Dataset', color='orange')
plt.xlabel('Species', color='orange')
plt.ylabel('Average Sepal Length (cm)', color='orange')

# Show the plot
plt.show()
# Out:
# C:\Users\ADIL SHAIKH\AppData\Local\Temp\ipykernel_22256\244691802.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='species', y='sepal_length', data=iris, ci=None)

# %% [markdown]
# # pie chart

# %%
# Create a pie chart
plt.figure(figsize=(6, 6))
iris['species'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'yellow'])

# Add glow effects
mplcyberpunk.add_glow_effects()

# Customize title
plt.title('Cyberpunk "Dark Mode" Pie Chart of Iris Species', color='orange')

# Show the plot
plt.show()

# %%
# Create a heatmap with dark background
plt.figure(figsize=(8, 6))
sns.heatmap(data, cmap='coolwarm')

# Add Cyberpunk style to the plot
plt.style.use("cyberpunk")
mplcyberpunk.add_glow_effects()

# Customize the plot
plt.title('Cyberpunk "Dark Mode" Heatmap', color='orange')
plt.xlabel('X-axis', color='orange')
plt.ylabel('Y-axis', color='orange')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22256\4242555216.py in <module>
#       1 # Create a heatmap with dark background
#       2 plt.figure(figsize=(8, 6))
# ----> 3 sns.heatmap(data, cmap='coolwarm')
#       4
#       5 # Add Cyberpunk style to the plot
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     444     """
#     445     # Initialize the plotter object
# --> 446     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                           annot_kws, cbar, cbar_kws, xticklabels,
#     448                           yticklabels, mask)
#
# ...

# %%
data = data.reshape(-1, 1)

# %%
b = 42  # Define the variable 'b'

def my_function():
    print(b)  # Access 'b' within the function

my_function()  # Call the function
# Out:
# 42

# %% [markdown]
# # Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import mplcyberpunk

# Assuming data is a 1D array
data = np.asarray(b)
data = data.reshape(-1, 1)  # Reshape to 2D

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(data, cmap='coolwarm')

# Add Cyberpunk style
plt.style.use("cyberpunk")
mplcyberpunk.add_glow_effects()

# Customize labels and title
plt.title('Cyberpunk "Dark Mode" Heatmap', color='orange')
plt.xlabel('X-axis', color='orange')
plt.ylabel('Y-axis', color='orange')

# Show the plot
plt.show()

# %% [markdown]
# # violin plot

# %%
# Generate random data (10x12 matrix)
data = np.random.rand(10, 12)
df = pd.DataFrame(data, columns=[f"Feature_{i}" for i in range(12)])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import mplcyberpunk

# Set the Cyberpunk style
plt.style.use("cyberpunk")

# Create the violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, palette="coolwarm")

# Add glow effects
mplcyberpunk.add_glow_effects()

# Customize labels and title
plt.title('Cyberpunk "Dark Mode" Violin Plot', color='orange')
plt.xlabel('Features', color='orange')
plt.ylabel('Values', color='orange')

# Show the plot
plt.show()

# %% [markdown]
# # swarm plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')

# %%
# Set the Cyberpunk style
plt.style.use("cyberpunk")

# Create the swarm plot
plt.figure(figsize=(10, 6))
sns.swarmplot(x="day", y="total_bill", data=tips, palette="bright")

# Add glow effects
mplcyberpunk.add_glow_effects()

# Customize labels and title
plt.title('Cyberpunk "Dark Mode" Swarm Plot of Tips Dataset', color='orange')
plt.xlabel('Day of the Week', color='orange')
plt.ylabel('Total Bill ($)', color='orange')

# Show the plot
plt.show()
# Out:
# C:\Users\ADIL SHAIKH\AppData\Local\Temp\ipykernel_22256\1591170390.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="day", y="total_bill", data=tips, palette="bright")

# %% [markdown]
# # Plot the line

# %%
# Generate random data for demonstration
x_values = np.linspace(0, 10, 100)
y_values = np.sin(x_values) + np.random.normal(0, 0.2, 100)

# Plot the line
plt.plot(x_values, y_values, marker="o", color="cyan", label="Cyberpunk Line")

# Customize the plot
plt.title("Cyberpunk-Style Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend()

# Show the plot
plt.show()

# %%
tips = sns.load_dataset("tips")

plt.style.use("dark_background")

sns.lineplot(x="total_bill", y="tip", data=tips)
plt.title("Cyberpunk-Style Line Plot: Tips vs. Total Bill")
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip ($)")
# Out:
# Text(0, 0.5, 'Tip ($)')

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np

# Load the Iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Create a Random Forest Classifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X, y)

# Get feature importances
importances = model.feature_importances_

# Convert the importances into a DataFrame
feature_importance = pd.DataFrame(importances, index=iris.feature_names, columns=["Importance"])

# Sort the DataFrame to plot
feature_importance = feature_importance.sort_values(by="Importance", ascending=False)

# Apply the cyberpunk style
plt.style.use("cyberpunk")

# Plot the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance.Importance, y=feature_importance.index, palette="viridis")
plt.title('Feature Importances with Iris Dataset')
plt.xlabel('Importance')
plt.ylabel('Features')

# Add the cyberpunk style
mplcyberpunk.add_glow_effects()

plt.show()
# Out:
# C:\Users\ADIL SHAIKH\AppData\Local\Temp\ipykernel_22256\3254551692.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_importance.Importance, y=feature_importance.index, palette="viridis")

# %% [markdown]
# # geographic map

# %%
import statsmodels.api as sm

from sklearn.datasets import fetch_openml
weather_dataset = fetch_openml(name='weather', version=1)

print(weather_dataset.DESCR)
# Out:
# The weather problem is a tiny dataset that we will use repeatedly to illustrate machine learning methods. Entirely fictitious, it supposedly concerns the conditions that are suitable for playing some unspecified game. In general, instances in a dataset are characterized by the values of features, or attributes, that measure different aspects of the instance. In this case there are four attributes: outlook, temperature, humidity, and windy. The outcome is whether to play or not.
#
# Downloaded from openml.org.

# %%
print(weather_dataset.data.head())
# Out:
#     outlook  temperature  humidity windy
# 0     sunny           85        85  True
# 1     sunny           80        90  True
# 2  overcast           83        86  True
# 3     rainy           70        96  True
# 4     rainy           68        80  True

# %%
print(weather_dataset.target.head())
# Out:
# 0     no
# 1     no
# 2    yes
# 3    yes
# 4    yes
# Name: play, dtype: category
# Categories (2, object): ['no', 'yes']

# %%
X = weather_dataset.data  # Features
y = weather_dataset.target  # Target variable

# %%
print(f"Features shape: {X.shape}")
print(f"Target shape: {y.shape}")
# Out:
# Features shape: (14, 4)
# Target shape: (14,)

# %%
import geopandas as gpd
from shapely.geometry import Point

# Create a GeoDataFrame with example data
data = {
    'City': ['Los Angeles', 'New York', 'Chicago'],
    'Latitude': [34.0522, 40.7128, 41.8781],
    'Longitude': [-118.2437, -74.0060, -87.6298]
}
df = pd.DataFrame(data)
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
gdf = gpd.GeoDataFrame(df, geometry=geometry)

# Set the style to cyberpunk
plt.style.use("cyberpunk")

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the cities on the axis
gdf.plot(ax=ax, color='white', markersize=100)

# Add glow effects
mplcyberpunk.add_glow_effects()

# Set the title and show the plot
ax.set_title('Cyberpunk Style Geographic Map', color='white', size=20)
plt.show()

# %% [markdown]
# # 3D plot

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
#Generate example data
import numpy as np
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# Set the style to cyberpunk
plt.style.use("cyberpunk")

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
surf = ax.plot_surface(x, y, z, cmap=mplcyberpunk.make_lines_glow())

# Add glow effects
mplcyberpunk.add_glow_effects()

# Show the plot
plt.show()

# %% [markdown]
# # choropleth plot

# %%
import geopandas as gpd
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Out:
# C:\Users\ADIL SHAIKH\AppData\Local\Temp\ipykernel_22256\2162896047.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
plt.style.use("cyberpunk")

fig, ax = plt.subplots(1, 1)

world.plot(column='pop_est', ax=ax, legend=True, cmap='plasma')

mplcyberpunk.add_glow_effects()

ax.set_title('Cyberpunk Style Choropleth Plot', color='white', size=20)

plt.show()
